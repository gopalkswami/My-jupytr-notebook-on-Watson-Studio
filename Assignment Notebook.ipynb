# %% [markdown]
# # My Jupytr Notebook on IBM Watson Studio

# %% [markdown]
# __Gopal Krishan__
# Freelancer

# %% [markdown]
# _I am interested in Data Science because data is going to be most important resource in coming times, & Data Science has the capability to control  this enormounous data & put it to best use for benefit of all the stakeholders._

# %% [markdown]
# ### I am goint to prove Commutative property of multiplication, which states that if we change the order of numbers for multiplication, it does not change the result.

# %%
if 2*4 == 4*2:
    print ("True")
else:
    print ("false")
# Out:
# True

# %% [markdown]
# -  Tom
# -  Dick
# -  Harry
# -  jerry
# -  Ron
# ***
#
# 1. Delhi
# 1. Mumbai
# 1. Chennai
# 1. Kolkata
# ***
# ![image.jpeg](attachment:image.jpeg)
